# %%
# !git clone https://github.com/YanYan0716/MPL
# Out:
# Cloning into 'MPL'...
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 1113 (delta 40), reused 42 (delta 22), pack-reused 1052
# Receiving objects: 100% (1113/1113), 306.74 KiB | 3.83 MiB/s, done.
# Resolving deltas: 100% (740/740), done.

# %%
# %cd MPL
# Out:
# /content/MPL

# %%
pip install tensorflow-addons
# Out:
# ...
#      |████████████████████████████████| 706kB 6.5MB/s
# ...

# %%
# !python train.py
# Out:
# Traceback (most recent call last):
#   File "train.py", line 35, in <module>
#     df_label = pd.read_csv(config.LABEL_FILE_PATH)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py", line 688, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py", line 454, in _read
#     parser = TextFileReader(fp_or_buf, **kwds)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py", line 948, in __init__
#     self._make_engine(self.engine)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py", line 1180, in _make_engine
#     self._engine = CParserWrapper(self.f, **self.options)
#   File "/usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py", line 2010, in __init__
#     self._reader = parsers.TextReader(src, **kwds)
#   File "pandas/_libs/parsers.pyx", line 382, in pandas._libs.parsers.TextReader.__cinit__
# ...

# %%
# %cd ..
# Out:
# /content

# %%
# !wget https://raw.githubusercontent.com/google-research/google-research/master/meta_pseudo_labels/data_utils.py
# Out:
# --2021-04-10 20:42:19--  https://raw.githubusercontent.com/google-research/google-research/master/meta_pseudo_labels/data_utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35822 (35K) [text/plain]
# Saving to: ‘data_utils.py’
#
# data_utils.py       100%[===================>]  34.98K  --.-KB/s    in 0.003s
#
# 2021-04-10 20:42:19 (10.2 MB/s) - ‘data_utils.py’ saved [35822/35822]

# %%
# !git clone https://github.com/google-research/google-research
# %cd google-research
# Out:
# Cloning into 'google-research'...
# remote: Enumerating objects: 323, done.
# remote: Counting objects: 100% (323/323), done.
# remote: Compressing objects: 100% (235/235), done.
# remote: Total 32188 (delta 93), reused 280 (delta 75), pack-reused 31865
# Receiving objects: 100% (32188/32188), 263.08 MiB | 28.93 MiB/s, done.
# Resolving deltas: 100% (17242/17242), done.
# Checking out files: 100% (11389/11389), done.
# /content/google-research

# %%
# !python -m meta_pseudo_labels.data_utils
# Out:
# 2021-04-10 20:44:37.813057: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Traceback (most recent call last):
#   File "/usr/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/usr/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/content/google-research/meta_pseudo_labels/data_utils.py", line 39, in <module>
#     from meta_pseudo_labels import augment
#   File "/content/google-research/meta_pseudo_labels/augment.py", line 54, in <module>
#     from tensorflow.contrib import image as image_ops
# ModuleNotFoundError: No module named 'tensorflow.contrib'

# %%
# !git clone https://github.com/kekmodel/MPL-pytorch
# Out:
# Cloning into 'MPL-pytorch'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 286 (delta 1), reused 1 (delta 0), pack-reused 280
# Receiving objects: 100% (286/286), 53.46 KiB | 13.37 MiB/s, done.
# Resolving deltas: 100% (179/179), done.

# %%
# %cd MPL-pytorch
# Out:
# /content/MPL-pytorch

# %%
# !python data.py

# %%
# !pwd
# Out:
# /content/MPL-pytorch

# %%
# !mv /content/google-research/MPL-pytorch /content/

# %%
# !python main.py --seed 5 --name cifar10-4K.5 --expand-labels --dataset cifar10 --num-classes 10 --num-labeled 4000 --total-steps 100 --eval-step 1000 --randaug 2 16 --batch-size 128 --teacher_lr 0.05 --student_lr 0.05 --weight-decay 5e-4 --ema 0.995 --nesterov --mu 7 --label-smoothing 0.15 --temperature 0.7 --threshold 0.6 --lambda-u 8 --warmup-steps 5000 --uda-steps 5000 --student-wait-steps 3000 --teacher-dropout 0.2 --student-dropout 0.2 --amp
# Out:
# 04/10/2021 21:44:24 - WARNING - __main__ -   Process rank: -1, device: cuda:0, distributed training: False, 16-bits training: True
# ...

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/hackathlon/trainFolder.zip -d /content/drive/MyDrive/hackathlon/

# %%
# !unzip /content/drive/MyDrive/hackathlon/testFolder.zip -d /content/drive/MyDrive/hackathlon/
# Out:
# Archive:  /content/drive/MyDrive/hackathlon/testFolder.zip
#    creating: /content/drive/MyDrive/hackathlon/testFolder/
#    creating: /content/drive/MyDrive/hackathlon/testFolder/0/
#   inflating: /content/drive/MyDrive/hackathlon/testFolder/0/00142ed0-95f1-4e21-8501-8e05fd4d14a5.jpg
#   inflating: /content/drive/MyDrive/hackathlon/testFolder/0/0026b8bc-dacf-4161-9abc-4c1b26932aee.jpg
#   inflating: /content/drive/MyDrive/hackathlon/testFolder/0/002c71f2-2734-430a-bc34-30c7f04339d1.jpg
#   inflating: /content/drive/MyDrive/hackathlon/testFolder/0/00479437-d21e-4ef9-a73e-501bae531d49.jpg
#   inflating: /content/drive/MyDrive/hackathlon/testFolder/0/00aeaf93-7fe1-4ebe-88eb-132dba572d8d.jpg
#   inflating: /content/drive/MyDrive/hackathlon/testFolder/0/00b7c58e-b4c9-4fbb-b633-0b4e907da2bb.jpg
#   inflating: /content/drive/MyDrive/hackathlon/testFolder/0/00e23869-744c-4b0c-b04c-db7394631c35.jpg
# ...
